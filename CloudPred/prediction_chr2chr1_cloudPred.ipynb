# %% [markdown]
# # Prediction based on CloudPred

# %%
import pickle
import scipy
import scipy.io
import os
import numpy as np
import scanpy as sc
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import sklearn.model_selection as sks
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
from matplotlib.pyplot import rc_context
import sklearn.metrics as skm
import collections
from sklearn.model_selection import KFold
import torch
import traceback
import random
import pathlib
import sklearn.mixture
import math
from lib_cloudpred import *

# %%
def get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers):
            df = markers.loc[markers["cluster"].isin(set_clusters),:]
            feat_tab = df.groupby('cluster')
            df2= feat_tab.apply(lambda x: x.sort_values(["avg_log2FC"], ascending=False)).reset_index(drop=True)
            feat=df2.groupby('cluster').head(n)
            idx_te= np.where(adata1_c.isin (feat.gene.values))[0] 
            idx_tr= np.where(adata_c.isin (adata1_c[idx_te]))[0]            

#             markers = ['HLA-DRA','HLA-DRB1','LYZ','CST3','TYROBP','AP1S2','CSTA','FCN1','MS4A6A','LST1','CYBB','CTSS','DUSP6','IL1B','SGK1','KLF4','CLEC7A','ATP2B1-AS1','MARCKS','SAT1','MYADM','IFI27','IFITM3','ISG15','APOBEC3A','IFI6','TNFSF10','MT2A','MX1','IFIT3','MNDA','S100A12','S100A9','S100A8','MAFB','VCAN','PLBD1','CXCL8','RNASE2','FCGR3A','MS4A7','CDKN1C','AIF1','COTL1','FCER1G','C1QA','RHOC','FCGR3B','IFITM2','NAMPT','G0S2','PROK2','CMTM2','BASP1','BCL2A1','SLC25A37','DEFA3','LTF','LCN2','CAMP','RETN','DEFA4','CD24','PGLYRP1','OLFM4']
#             idx_tr= np.where(adata_c.isin (markers))[0]
#             idx_te= np.where(adata1_c.isin (markers))[0]

            Xtrain = list(map(lambda x: (x[0][:,idx_tr], *x[1:]), Xtrain))
            Xtest = list(map(lambda x: (x[0][:,idx_te], *x[1:]), Xtest))
            Xtrain = list(map(lambda x: (x[0].todense(), *x[1:]), Xtrain))
            Xtest  = list(map(lambda x: (x[0].todense(), *x[1:]), Xtest))    
            return Xtrain,Xtest

# %%
def cloud_pred(Xtrain, Xtest, seed, set_centers):
    
            best_model = None
            best_score = float("inf")
            print("start cloudpred")
            print(seed)
            for centers in set_centers:
                model, res = train(Xtrain, [], centers, regression=False, seed=seed)
                print("best score for center"+ str(res["loss"])+"_"+str( centers))
                print(res)
                if res["loss"] < best_score:
                    best_model = model
                    best_score = res["loss"]
                    best_centers = centers
                    res_ = res
            with open(path+'/cloudpred_model'+label+"_"+str(seed)+"_"+str(best_centers)+"_"+str(n), 'wb') as fp:
                 pickle.dump(best_model, fp)         
            print("##Validation")
            print(res_)
            res = eval(best_model, Xtest, regression=False,path=path+"/"+label+"/"+str(seed)+"_"+str(n)+"_")
            print("##Test")
            print(res)

# %% [markdown]
# ## 1.Load data (all cells, Monocytes, Monocytes+neutrophils, Neutrophils)

# %%
data = collections.defaultdict(list)
path= "../../2cohorts/chr2chr1/"
files= ['Xtest','Xall','Ctest','Call','state']
ext= ['','_mono','_mono_neu','_neu']
for fl in files:
    for ex in ext:
        car= fl+ex
        with open(path+fl+ex+".pkl", "rb") as f:
            buf = pickle.load(f)
        if fl ==  'Xall':
            buf=np.concatenate([buf[0],buf[1]])
        data[car]=buf

# %% [markdown]
# ## Load marker genes

# %%
markers= pd.read_csv('../scripts/marker_cohort2')
markers["avg_log2FC"] = np.abs(markers["avg_log2FC"])

# %% [markdown]
# ## 2.Prediction based on Monocytes

# %% [markdown]
# ### 2.1.Using top 50 genes per cluster

# %%
label= 'mono'
Xtrain = data['Xall_mono']
Xtest = data['Xtest_mono']
set_clusters=[7,11,3,4,6]
n = 50
adata_c = data['Call_mono']
adata1_c = data['Ctest_mono']
Xtrain,Xtest = get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers)
state = data['state']

# %% [markdown]
# ### 2.1.1.CloudPred model

# %%
for seed in [0,42,10,1234,4321]:
    cloud_pred(Xtrain, Xtest, seed, [5])
# Out:
# start cloudpred
# 0
# -----------------------------------------------------------
# Iteration #1:
# {'loss': 0.5924975875765085, 'accuracy': 0.7, 'soft': 0.6008832603693008, 'auc': 0.76, 'r2': nan}
# -----------------------------------------------------------
# Iteration #101:
# {'loss': 0.5948702827095985, 'accuracy': 0.7, 'soft': 0.5999908357858658, 'auc': 0.76, 'r2': nan}
# -----------------------------------------------------------
# Iteration #201:
# {'loss': 0.5951076559722424, 'accuracy': 0.7, 'soft': 0.5998267471790314, 'auc': 0.8, 'r2': nan}
# -----------------------------------------------------------
# Iteration #301:
# {'loss': 0.595208403468132, 'accuracy': 0.7, 'soft': 0.5997719436883926, 'auc': 0.8, 'r2': nan}
# -----------------------------------------------------------
# Iteration #401:
# {'loss': 0.5946061160415411, 'accuracy': 0.7, 'soft': 0.6003642529249191, 'auc': 0.76, 'r2': nan}
# -----------------------------------------------------------
# Iteration #501:
# {'loss': 0.5937930531799793, 'accuracy': 0.7, 'soft': 0.6003712773323059, 'auc': 0.76, 'r2': nan}
# -----------------------------------------------------------
# Iteration #601:
# {'loss': 0.5935249868780375, 'accuracy': 0.7, 'soft': 0.6004067301750183, 'auc': 0.76, 'r2': nan}
# -----------------------------------------------------------
# Iteration #701:
# {'loss': 0.593268334120512, 'accuracy': 0.7, 'soft': 0.6004522711038589, 'auc': 0.76, 'r2': nan}
# -----------------------------------------------------------
# Iteration #801:
# {'loss': 0.5930394068360328, 'accuracy': 0.7, 'soft': 0.6004818797111511, 'auc': 0.76, 'r2': nan}
# -----------------------------------------------------------
# Iteration #901:
# {'loss': 0.592806588113308, 'accuracy': 0.7, 'soft': 0.6005266100168228, 'auc': 0.76, 'r2': nan}
# **********************************************
# {'loss': 0.5924975875765085, 'accuracy': 0.7, 'soft': 0.6008832603693008, 'auc': 0.76, 'r2': nan}
# best score for center0.5924975875765085_5
# {'loss': 0.5924975875765085, 'accuracy': 0.7, 'soft': 0.6008832603693008, 'auc': 0.76, 'r2': nan}
# ##Validation
# {'loss': 0.5924975875765085, 'accuracy': 0.7, 'soft': 0.6008832603693008, 'auc': 0.76, 'r2': nan}
# eval------------------------eval
# -----------------------------------------------------------
# Iteration #1:
# {'loss': 20.631345960828995, 'accuracy': 0.5185185185185185, 'soft': 0.5185185185185206, 'auc': 0.6703296703296704, 'r2': nan}
# **********************************************
# {'loss': 20.631345960828995, 'accuracy': 0.5185185185185185, 'soft': 0.5185185185185206, 'auc': 0.6703296703296704, 'r2': nan}
# ##Test
# {'loss': 20.631345960828995, 'accuracy': 0.5185185185185185, 'soft': 0.5185185185185206, 'auc': 0.6703296703296704, 'r2': nan}
# start cloudpred
# 42
# -----------------------------------------------------------
# Iteration #1:
# {'loss': 0.6539407551288605, 'accuracy': 0.7, 'soft': 0.5467685997486115, 'auc': 0.5833333333333334, 'r2': nan}
# -----------------------------------------------------------
# Iteration #101:
# {'loss': 0.6680970937013626, 'accuracy': 0.7, 'soft': 0.5348054558038712, 'auc': 0.5833333333333334, 'r2': nan}
# -----------------------------------------------------------
# Iteration #201:
# {'loss': 0.6726839601993561, 'accuracy': 0.6, 'soft': 0.5323941856622696, 'auc': 0.5833333333333334, 'r2': nan}
# -----------------------------------------------------------
# Iteration #301:
# {'loss': 0.6737645000219346, 'accuracy': 0.6, 'soft': 0.5320795267820358, 'auc': 0.5833333333333334, 'r2': nan}
# -----------------------------------------------------------
# Iteration #401:
# {'loss': 0.674063666164875, 'accuracy': 0.6, 'soft': 0.5321949154138566, 'auc': 0.5833333333333334, 'r2': nan}
# -----------------------------------------------------------
# Iteration #501:
# {'loss': 0.6742501586675644, 'accuracy': 0.6, 'soft': 0.5323644489049911, 'auc': 0.5833333333333334, 'r2': nan}
# -----------------------------------------------------------
# Iteration #601:
# {'loss': 0.6892595320940018, 'accuracy': 0.5, 'soft': 0.5317543417215347, 'auc': 0.5833333333333334, 'r2': nan}
# -----------------------------------------------------------
# Iteration #701:
# {'loss': 0.6692395329475402, 'accuracy': 0.6, 'soft': 0.5410983353853226, 'auc': 0.5833333333333334, 'r2': nan}
# -----------------------------------------------------------
# Iteration #801:
# {'loss': 0.6657266214489936, 'accuracy': 0.7, 'soft': 0.5431426256895066, 'auc': 0.5833333333333334, 'r2': nan}
# -----------------------------------------------------------
# Iteration #901:
# {'loss': 0
# -----------------------------------------------------------
# Iteration #1:
# {'loss': 0.8199242913280613, 'accuracy': 0.5, 'soft': 0.5809808798134327, 'auc': 0.7916666666666667, 'r2': nan}
# -----------------------------------------------------------
# Iteration #101:
# {'loss': 0.7932938120909967, 'accuracy': 0.5, 'soft': 0.588000426441431, 'auc': 0.7916666666666667, 'r2': nan}
# -----------------------------------------------------------
# Iteration #201:
# {'loss': 0.7890391920227557, 'accuracy': 0.5, 'soft': 0.593859949707985, 'auc': 0.75, 'r2': nan}
# -----------------------------------------------------------
# Iteration #301:
# {'loss': 0.7771352445473895, 'accuracy': 0.5, 'soft': 0.6008887387812137, 'auc': 0.75, 'r2': nan}
# -----------------------------------------------------------
# Iteration #401:
# {'loss': 0.7769559927517549, 'accuracy': 0.5, 'soft': 0.6040032736957073, 'auc': 0.75, 'r2': nan}
# -----------------------------------------------------------
# Iteration #501:
# {'loss': 0.7613650968065485, 'accuracy': 0.6, 'soft': 0.6106727786362172, 'auc': 0.75, 'r2': nan}
# -----------------------------------------------------------
# Iteration #601:
# {'loss': 0.752870156429708, 'accuracy': 0.6, 'soft': 0.6127478592097759, 'auc': 0.75, 'r2': nan}
# -----------------------------------------------------------
# Iteration #701:
# {'loss': 0.7511049432912842, 'accuracy': 0.6, 'soft': 0.6128285825252533, 'auc': 0.75, 'r2': nan}
# -----------------------------------------------------------
# Iteration #801:
# {'loss': 0.7490858046105131, 'accuracy': 0.6, 'soft': 0.613502175360918, 'auc': 0.75, 'r2': nan}
# -----------------------------------------------------------
# Iteration #901:
# {'loss': 0.738894062768668, 'accuracy': 0.6, 'soft': 0.6154857784509659, 'auc': 0.75, 'r2': nan}
# **********************************************
# {'loss': 0.7353629622608423, 'accuracy': 0.6, 'soft': 0.6156022310256958, 'auc': 0.75, 'r2': nan}
# best score for center0.7353629622608423_5
# {'loss': 0.7353629622608423, 'accuracy': 0.6, 'soft': 0.6156022310256958, 'auc': 0.75, 'r2': nan}
# ##Validation
# {'loss': 0.7353629622608423, 'accuracy': 0.6, 'soft': 0.6156022310256958, 'auc': 0.75, 'r2': nan}
# eval------------------------eval
# -----------------------------------------------------------
# Iteration #1:
# {'loss': 21.116343604193794, 'accuracy': 0.48148148148148145, 'soft': 0.48148148148148145, 'auc': 0.2472527472527472, 'r2': nan}
# **********************************************
# {'loss': 21.116343604193794, 'accuracy': 0.48148148148148145, 'soft': 0.48148148148148145, 'auc': 0.2472527472527472, 'r2': nan}
# ##Test
# {'loss': 21.116343604193794, 'accuracy': 0.48148148148148145, 'soft': 0.48148148148148145, 'auc': 0.2472527472527472, 'r2': nan}

# %% [markdown]
# ## 3.Prediction based on Monocytes+Neutrophils

# %% [markdown]
# ### 3.1.Using top 50 genes per cluster

# %%
label='mono_neu'
Xtrain = data['Xall_mono_neu']
Xtest = data['Xtest_mono_neu']
set_clusters=[7,11,3,4,6,9,14]
n = 50
adata_c = data['Call_mono_neu']
adata1_c = data['Ctest_mono_neu']
Xtrain,Xtest = get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers)
state = data['state']

# %% [markdown]
# ### 3.1.2.GMM_class

# %%
for seed in [0,42,10,1234,4321]:
    cloud_pred(Xtrain, Xtest, seed, [7,5])

# %% [markdown]
# ### 3.2.Using top 20 genes per cluster

# %%
n = 20
Xtrain,Xtest = get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers)

# %% [markdown]
# ### 3.2.2.GMM class

# %%
for seed in [0,42,10,1234,4321]:
    cloud_pred(Xtrain, Xtest, seed, [7,5])

# %% [markdown]
# ### 3.3.Using top 100 genes per cluster

# %%
n = 100
Xtrain,Xtest = get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers)

# %% [markdown]
# ### 3.3.2.GMM class

# %%
for seed in [0,42,10,1234,4321]:
    cloud_pred(Xtrain, Xtest, seed, [7,5])

# %% [markdown]
# ## 4.Prediction based on Neutrophils

# %% [markdown]
# ### 4.1.Using top 50 genes per cluster

# %%
label='neu'
Xtrain = data['Xall_neu']
Xtest = data['Xtest_neu']
set_clusters=[9,14]
n = 50
adata_c = data['Call_neu']
adata1_c = data['Ctest_neu']
Xtrain,Xtest = get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers)
state = data['state']

# %% [markdown]
# ### 4.1.2.GMM_class

# %%
for seed in [0,42,10,1234,4321]:
    cloud_pred(Xtrain, Xtest, seed, [2])

# %% [markdown]
# ### 4.2.Using top 20 genes per cluster

# %%
n = 20
Xtrain,Xtest = get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers)

# %% [markdown]
# ### 4.2.2.GMM class

# %%
for seed in [0,42,10,1234,4321]:
    cloud_pred(Xtrain, Xtest, seed, [2])

# %% [markdown]
# ### 4.3.Using top 100 genes per cluster

# %%
n = 100
Xtrain,Xtest = get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers)

# %% [markdown]
# ### 4.3.2.GMM class

# %%
for seed in [0,42,10,1234,4321]:
    cloud_pred(Xtrain, Xtest, seed,
 'auc': 0.7916666666666666, 'r2': nan}
# -----------------------------------------------------------
# Iteration #301:
# {'loss': 0.5350322313606739, 'accuracy': 0.6, 'soft': 0.6301824495196342, 'auc': 0.7916666666666666, 'r2': nan}
# -----------------------------------------------------------
# Iteration #401:
# {'loss': 0.5357907339930534, 'accuracy': 0.6, 'soft': 0.629750844836235, 'auc': 0.7916666666666666, 'r2': nan}
# -----------------------------------------------------------
# Iteration #501:
# {'loss': 0.5360988266766071, 'accuracy': 0.6, 'soft': 0.6296892642974854, 'auc': 0.7916666666666666, 'r2': nan}
# -----------------------------------------------------------
# Iteration #601:
# {'loss': 0.5362218253314495, 'accuracy': 0.6, 'soft': 0.6297757625579834, 'auc': 0.7916666666666666, 'r2': nan}
# -----------------------------------------------------------
# Iteration #701:
# {'loss': 0.5362746126949787, 'accuracy': 0.6, 'soft': 0.6299177780747414, 'auc': 0.7916666666666666, 'r2': nan}
# -----------------------------------------------------------
# Iteration #801:
# {'loss': 0.5362978547811508, 'accuracy': 0.6, 'soft': 0.6300790324807167, 'auc': 0.7916666666666666, 'r2': nan}
# -----------------------------------------------------------
# Iteration #901:
# {'loss': 0.6088615505956113, 'accuracy': 0.8, 'soft': 0.7364945482462645, 'auc': 0.7916666666666666, 'r2': nan}
# **********************************************
# {'loss': 0.5225160539150238, 'accuracy': 0.9, 'soft': 0.6430272936820984, 'auc': 0.7916666666666666, 'r2': nan}
# best score for center0.5225160539150238_21
# {'loss': 0.5225160539150238, 'accuracy': 0.9, 'soft': 0.6430272936820984, 'auc': 0.7916666666666666, 'r2': nan}
# -----------------------------------------------------------
# Iteration #1:
# {'loss': 0.6409786850214004, 'accuracy': 0.8, 'soft': 0.6041483506560326, 'auc': 0.75, 'r2': nan}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-940d2ed73201> in <module>
#       1 for seed in [0,42,10,1234,4321]:
# ----> 2     cloud_pred(Xtrain, Xtest, seed, [21,5])
#
# <ipython-input-3-bed1f35bd1ee> in cloud_pred(Xtrain, Xtest, seed, set_centers)
#       6             print(seed)
#       7             for centers in set_centers:
# ----> 8                 model, res = train(Xtrain, [], centers, regression=False, seed=seed)
#       9                 print("best score for center"+ str(res["loss"])+"_"+str( centers))
#      10                 print(res)
#
# /beegfs/prj/NUM_CODEX_PLUS/Amina/Prediction_scOmics/CloudPred/lib_cloudpred.py in train(Xtrain, Xvalid, centers, regression, seed)
#      97     #________________________________________________________________________
#      98
# ---> 99     return train_classifier(Xtrain, Xvalid, [], classifier, regularize=reg,
#     100                                             iterations=1000, eta=1e-4, stochastic=True,
#     101                                             regression=regression, seed=seed)
#
# /beegfs/prj/NUM_CODEX_PLUS/Amina/Prediction_scOmics/CloudPred/lib_cloudpred.py in train_classifier(Xtrain, Xvalid, Xtest, classifier, regularize, eta, iterations, stochastic, cuda, state, regression, path, seed)
#     306                     if dataset == "train" and (stochastic or start + 1 == len(X)):
#     307                         optimizer.zero_grad()
# --> 308                         loss.backward()
#     309                         optimizer.step()
#     310                     elif dataset == "test":
#
# ~/.local/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/.local/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %% [markdown]
# ### 5.2.Using top 20 genes per cluster

# %%
Xtrain = data['Xall']
Xtest = data['Xtest']
n = 20
Xtrain,Xtest = get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers)

# %% [markdown]
# ### 5.2.2.GMM class

# %%
for seed in [0,42,10,1234,4321]:
    cloud_pred(Xtrain, Xtest, seed, [21,5])

# %% [markdown]
# ### 5.3.Using top 100 genes per cluster

# %%
Xtrain = data['Xall']
Xtest = data['Xtest']
n = 100
Xtrain,Xtest = get_data(Xtrain,Xtest,set_clusters,n,adata_c,adata1_c,markers)

# %% [markdown]
# ### 5.3.2.GMM class

# %%
for seed in [0,42,10,1234,4321]:
    cloud_pred(Xtrain, Xtest, seed, [21,5])
